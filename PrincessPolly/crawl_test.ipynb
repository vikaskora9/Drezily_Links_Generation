# %%
import requests
import json
# Out:
# /Users/shardakora/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
res = json.loads(requests.post('https://search.nosto.com/v1/graphql', data=json.dumps({"query":"\n\t\t\tquery($categoryPath: String, $filters: [InputSearchTopLevelFilter!], $sortOrder: [InputSearchSort!], $customRules: [InputSearchRule!]) {\n\t\t\t\tsearch(\n\t\t\t\t\taccountId: \"shopify-7660404818\"\n\t\t\t\t\tproducts: {\n\t\t\t\t\t\tcategoryPath: $categoryPath,\n\t\t\t\t\t\tsize: 100,\n\t\t\t\t\t\tfrom: 0,\n\t\t\t\t\t\tfilter: $filters,\n\t\t\t\t\t\tsort: $sortOrder\n\t\t\t\t\t},\n\t\t\t\t\tcustomRules: $customRules\n\t\t\t\t) {\n\t\t\t\t\tproducts {\n\t\t\t\t\t\thits {\n\t\t\t\t\t\t\tdatePublished\n\t\t\t\t\t\t\turl\n\t\t\t\t\t\t\tname\n\t\t\t\t\t\t\tproductId\n\t\t\t\t\t\t\timageUrl\n\t\t\t\t\t\t\tthumbUrl\n\t\t\t\t\t\t\tbrand\n\t\t\t\t\t\t\tavailability\n\t\t\t\t\t\t\tprice\n\t\t\t\t\t\t\tlistPrice\n\t\t\t\t\t\t\tcategoryIds\n\t\t\t\t\t\t\tinventoryLevel\n\t\t\t\t\t\t\ttags1\n\t\t\t\t\t\t\ttags2\n\t\t\t\t\t\t\ttags3\n\t\t\t\t\t\t\tpriceCurrencyCode\n\t\t\t\t\t\t\talternateImageUrls\n\t\t\t\t\t\t\tskus {\n\t\t\t\t\t\t\t\tid\n\t\t\t\t\t\t\t\tname\n\t\t\t\t\t\t\t\tprice\n\t\t\t\t\t\t\t\turl\n\t\t\t\t\t\t\t\timageUrl\n\t\t\t\t\t\t\t\tavailability\n\t\t\t\t\t\t\t\tcustomFields {\n\t\t\t\t\t\t\t\t\tkey\n\t\t\t\t\t\t\t\t\tvalue\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\tcustomFields {\n\t\t\t\t\t\t\t\tkey\n\t\t\t\t\t\t\t\tvalue\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t}\n\t\t\t\t\t\ttotal\n\t\t\t\t\t\tsize\n\t\t\t\t\t}\n\t\t\t\t}\n\t\t\t}\n    ","variables":{"categoryPath":"Tops","filters":[{"field":"availability","value":["InStock"]},{"not":[{"any":[{"field":"tags1","value":"pfs:hidden"},{"field":"tags2","value":"pfs:hidden"},{"field":"tags3","value":"pfs:hidden"}]}]}],"sortOrder":[],"customRules":[]}})).text)

# %%
res['data']['search']['products']
# Out:
# {'hits': [{'datePublished': 1732838420000.0,
#    'url': 'https://www.princesspolly.com.au/products/carefree-days-cowl-neck-top-black',
#    'name': 'Carefree Days Cowl Neck Top Black',
#    'productId': '6894106738760',
#    'imageUrl': 'https://cdn.shopify.com/s/files/1/0076/6040/4818/files/0-modelinfo-elise-us2_fb939cb2-fa17-4ac6-afb6-0ec8ddc74094.jpg?v=1735628112',
#    'thumbUrl': 'https://cdn.shopify.com/s/files/1/0076/6040/4818/files/0-modelinfo-elise-us2_fb939cb2-fa17-4ac6-afb6-0ec8ddc74094_large.jpg?v=1735628112',
#    'brand': 'Princess Polly Lower Impact',
#    'availability': 'InStock',
#    'price': 50.0,
#    'listPrice': 50.0,
#    'categoryIds': ['143381659730',
#     '268189728840',
#     '273160372296',
#     '266444767304',
#     '274747162696',
#     '260663705672',
#     '276534165576',
#     '266574987336',
#     '164923703378',
#     '269484720200',
#     '207433597000',
#     '272799957064',
#     '276083736648',
#     '275068387400',
#     '264929574984',
# ...
